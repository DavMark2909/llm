# %% [markdown]
# Establish the connection to the database or the content from the url

# %%
# import yaml
# from sqlalchemy import create_engine
# from langchain_community.utilities import SQLDatabase

# with open('../config/config.yml', 'r') as file:
#     config = yaml.safe_load(file)

# mysql_config = config.get('mysql')

# username = mysql_config.get('username')
# password = mysql_config.get('password')
# host = mysql_config.get('host')
# port = mysql_config.get('port')
# database = mysql_config.get('database')

# connection_string = f"mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}"
# engine = create_engine(connection_string)

# db = SQLDatabase(engine)

# %%
from pyprojroot import here

from sqlalchemy import create_engine
from langchain_community.utilities import SQLDatabase

database_path = here("data/sqldb.db")

connection_string = f"sqlite:///{database_path}"
engine = create_engine(connection_string, echo=True)
db = SQLDatabase(engine)
# Out:
# 2025-02-27 10:29:07,929 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:29:07,929 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2025-02-27 10:29:07,930 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,931 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:29:07,931 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:29:07,931 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2025-02-27 10:29:07,931 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,932 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_temp_master WHERE type='table' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2025-02-27 10:29:07,932 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,932 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Album")
# 2025-02-27 10:29:07,932 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,933 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Artist")
# 2025-02-27 10:29:07,933 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,933 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Customer")
# 2025-02-27 10:29:07,933 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,934 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Employee")
# 2025-02-27 10:29:07,934 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,934 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Genre")
# 2025-02-27 10:29:07,934 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,935 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Invoice")
# 2025-02-27 10:29:07,935 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,935 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("InvoiceLine")
# 2025-02-27 10:29:07,935 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,935 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("MediaType")
# 2025-02-27 10:29:07,936 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,936 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Playlist")
# 2025-02-27 10:29:07,936 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,936 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("PlaylistTrack")
# 2025-02-27 10:29:07,936 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,937 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Track")
# 2025-02-27 10:29:07,937 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,937 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,937 INFO sqlalchemy.engine.Engine [raw sql] ('Album',)
# 2025-02-27 10:29:07,938 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,938 INFO sqlalchemy.engine.Engine [raw sql] ('Artist',)
# 2025-02-27 10:29:07,938 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,938 INFO sqlalchemy.engine.Engine [raw sql] ('Customer',)
# 2025-02-27 10:29:07,938 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,939 INFO sqlalchemy.engine.Engine [raw sql] ('Employee',)
# 2025-02-27 10:29:07,939 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,939 INFO sqlalchemy.engine.Engine [raw sql] ('Genre',)
# 2025-02-27 10:29:07,939 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,939 INFO sqlalchemy.engine.Engine [raw sql] ('Invoice',)
# 2025-02-27 10:29:07,940 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,940 INFO sqlalchemy.engine.Engine [raw sql] ('InvoiceLine',)
# 2025-02-27 10:29:07,940 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,940 INFO sqlalchemy.engine.Engine [raw sql] ('MediaType',)
# 2025-02-27 10:29:07,940 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,941 INFO sqlalchemy.engine.Engine [raw sql] ('Playlist',)
# 2025-02-27 10:29:07,941 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,941 INFO sqlalchemy.engine.Engine [raw sql] ('PlaylistTrack',)
# 2025-02-27 10:29:07,941 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,941 INFO sqlalchemy.engine.Engine [raw sql] ('Track',)
# 2025-02-27 10:29:07,942 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Album")
# 2025-02-27 10:29:07,942 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,942 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,942 INFO sqlalchemy.engine.Engine [raw sql] ('Album',)
# 2025-02-27 10:29:07,943 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Artist")
# 2025-02-27 10:29:07,944 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,944 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("Artist")
# 2025-02-27 10:29:07,944 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,945 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,945 INFO sqlalchemy.engine.Engine [raw sql] ('Artist',)
# 2025-02-27 10:29:07,945 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Customer")
# 2025-02-27 10:29:07,946 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,946 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,946 INFO sqlalchemy.engine.Engine [raw sql] ('Customer',)
# 2025-02-27 10:29:07,946 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Employee")
# 2025-02-27 10:29:07,946 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,947 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,947 INFO sqlalchemy.engine.Engine [raw sql] ('Employee',)
# 2025-02-27 10:29:07,947 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Genre")
# 2025-02-27 10:29:07,948 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,948 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("Genre")
# 2025-02-27 10:29:07,948 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,949 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,949 INFO sqlalchemy.engine.Engine [raw sql] ('Genre',)
# 2025-02-27 10:29:07,949 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Invoice")
# 2025-02-27 10:29:07,949 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,949 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,950 INFO sqlalchemy.engine.Engine [raw sql] ('Invoice',)
# 2025-02-27 10:29:07,950 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("InvoiceLine")
# 2025-02-27 10:29:07,950 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,950 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,950 INFO sqlalchemy.engine.Engine [raw sql] ('InvoiceLine',)
# 2025-02-27 10:29:07,951 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("MediaType")
# 2025-02-27 10:29:07,951 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,951 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("MediaType")
# 2025-02-27 10:29:07,951 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,951 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,952 INFO sqlalchemy.engine.Engine [raw sql] ('MediaType',)
# 2025-02-27 10:29:07,952 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Playlist")
# 2025-02-27 10:29:07,952 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,952 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("Playlist")
# 2025-02-27 10:29:07,953 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,953 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,953 INFO sqlalchemy.engine.Engine [raw sql] ('Playlist',)
# 2025-02-27 10:29:07,953 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("PlaylistTrack")
# 2025-02-27 10:29:07,954 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,954 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,955 INFO sqlalchemy.engine.Engine [raw sql] ('PlaylistTrack',)
# 2025-02-27 10:29:07,956 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Track")
# 2025-02-27 10:29:07,956 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,956 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,957 INFO sqlalchemy.engine.Engine [raw sql] ('Track',)
# 2025-02-27 10:29:07,957 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Album")
# 2025-02-27 10:29:07,957 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,958 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_AlbumArtistId")
# 2025-02-27 10:29:07,958 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,958 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Artist")
# 2025-02-27 10:29:07,958 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,959 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Artist")
# 2025-02-27 10:29:07,959 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,959 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Artist")
# 2025-02-27 10:29:07,959 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,960 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Customer")
# 2025-02-27 10:29:07,960 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,960 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_CustomerSupportRepId")
# 2025-02-27 10:29:07,960 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,960 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Employee")
# 2025-02-27 10:29:07,961 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,961 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_EmployeeReportsTo")
# 2025-02-27 10:29:07,961 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,962 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Genre")
# 2025-02-27 10:29:07,962 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,963 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Genre")
# 2025-02-27 10:29:07,963 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,963 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Genre")
# 2025-02-27 10:29:07,963 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,963 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Invoice")
# 2025-02-27 10:29:07,964 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,964 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_InvoiceCustomerId")
# 2025-02-27 10:29:07,964 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,965 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("InvoiceLine")
# 2025-02-27 10:29:07,965 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,965 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_InvoiceLineTrackId")
# 2025-02-27 10:29:07,965 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,966 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_InvoiceLineInvoiceId")
# 2025-02-27 10:29:07,966 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,966 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("MediaType")
# 2025-02-27 10:29:07,967 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,967 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("MediaType")
# 2025-02-27 10:29:07,967 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,967 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("MediaType")
# 2025-02-27 10:29:07,968 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,968 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Playlist")
# 2025-02-27 10:29:07,968 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,969 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Playlist")
# 2025-02-27 10:29:07,969 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,969 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Playlist")
# 2025-02-27 10:29:07,969 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,969 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("PlaylistTrack")
# 2025-02-27 10:29:07,970 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,970 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_PlaylistTrackTrackId")
# 2025-02-27 10:29:07,970 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,970 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_PlaylistTrackPlaylistId")
# 2025-02-27 10:29:07,971 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,972 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Track")
# 2025-02-27 10:29:07,972 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,972 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_TrackMediaTypeId")
# 2025-02-27 10:29:07,972 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,973 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_TrackGenreId")
# 2025-02-27 10:29:07,973 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,973 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_TrackAlbumId")
# 2025-02-27 10:29:07,973 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,974 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Album")
# 2025-02-27 10:29:07,975 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,975 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_AlbumArtistId")
# 2025-02-27 10:29:07,975 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,976 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,976 INFO sqlalchemy.engine.Engine [raw sql] ('Album',)
# 2025-02-27 10:29:07,977 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Artist")
# 2025-02-27 10:29:07,977 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,977 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Artist")
# 2025-02-27 10:29:07,977 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,978 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Artist")
# 2025-02-27 10:29:07,978 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,978 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,978 INFO sqlalchemy.engine.Engine [raw sql] ('Artist',)
# 2025-02-27 10:29:07,979 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Customer")
# 2025-02-27 10:29:07,979 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,979 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_CustomerSupportRepId")
# 2025-02-27 10:29:07,979 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,980 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,980 INFO sqlalchemy.engine.Engine [raw sql] ('Customer',)
# 2025-02-27 10:29:07,981 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Employee")
# 2025-02-27 10:29:07,982 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,982 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_EmployeeReportsTo")
# 2025-02-27 10:29:07,982 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,983 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,983 INFO sqlalchemy.engine.Engine [raw sql] ('Employee',)
# 2025-02-27 10:29:07,984 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Genre")
# 2025-02-27 10:29:07,984 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,984 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Genre")
# 2025-02-27 10:29:07,984 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,985 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Genre")
# 2025-02-27 10:29:07,985 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,985 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,985 INFO sqlalchemy.engine.Engine [raw sql] ('Genre',)
# 2025-02-27 10:29:07,986 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Invoice")
# 2025-02-27 10:29:07,986 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,986 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_InvoiceCustomerId")
# 2025-02-27 10:29:07,986 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,986 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,987 INFO sqlalchemy.engine.Engine [raw sql] ('Invoice',)
# 2025-02-27 10:29:07,987 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("InvoiceLine")
# 2025-02-27 10:29:07,987 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,988 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_InvoiceLineTrackId")
# 2025-02-27 10:29:07,988 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,988 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_InvoiceLineInvoiceId")
# 2025-02-27 10:29:07,988 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,988 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,988 INFO sqlalchemy.engine.Engine [raw sql] ('InvoiceLine',)
# 2025-02-27 10:29:07,989 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("MediaType")
# 2025-02-27 10:29:07,989 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,989 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("MediaType")
# 2025-02-27 10:29:07,989 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,990 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("MediaType")
# 2025-02-27 10:29:07,990 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,990 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,990 INFO sqlalchemy.engine.Engine [raw sql] ('MediaType',)
# 2025-02-27 10:29:07,990 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Playlist")
# 2025-02-27 10:29:07,991 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,991 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Playlist")
# 2025-02-27 10:29:07,991 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,991 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Playlist")
# 2025-02-27 10:29:07,991 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,992 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,992 INFO sqlalchemy.engine.Engine [raw sql] ('Playlist',)
# 2025-02-27 10:29:07,992 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("PlaylistTrack")
# 2025-02-27 10:29:07,992 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,992 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_PlaylistTrackTrackId")
# 2025-02-27 10:29:07,993 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,993 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_PlaylistTrackPlaylistId")
# 2025-02-27 10:29:07,993 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,993 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("sqlite_autoindex_PlaylistTrack_1")
# 2025-02-27 10:29:07,993 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,994 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,994 INFO sqlalchemy.engine.Engine [raw sql] ('PlaylistTrack',)
# 2025-02-27 10:29:07,994 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Track")
# 2025-02-27 10:29:07,994 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,995 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_TrackMediaTypeId")
# 2025-02-27 10:29:07,995 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,996 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_TrackGenreId")
# 2025-02-27 10:29:07,996 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,997 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_TrackAlbumId")
# 2025-02-27 10:29:07,998 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-27 10:29:07,998 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2025-02-27 10:29:07,998 INFO sqlalchemy.engine.Engine [raw sql] ('Track',)
# 2025-02-27 10:29:08,003 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# Create the connection to the database by inputing the api_key and making the connection to the clod provider

# %%
from getpass import getpass
import os
from langchain.chat_models import init_chat_model

os.environ["OPENAI_API_KEY"] = getpass()
llm = init_chat_model("gpt-4o-mini", model_provider="openai")

# %% [markdown]
# Create the fileds for the State that is going to be parsed among the agent pipeline

# %%
from typing_extensions import TypedDict


class State(TypedDict):
    question: str
    query: str
    result: str
    answer: str

# sets the fields that are passed among the states

# %% [markdown]
# Populate the model with the predifined prompts designed to tell the model in what direction it should navigate the response

# %%
from langchain import hub

query_prompt_template = hub.pull("langchain-ai/sql-query-system-prompt")

assert len(query_prompt_template.messages) == 1
query_prompt_template.messages[0].pretty_print()
# Out:
# /Users/mark/Documents/Research/LLM_MODEL/.venv/lib/python3.11/site-packages/langsmith/client.py:253: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# ================================ System Message ================================
#
# Given an input question, create a syntactically correct {dialect} query to run to help find the answer. Unless the user specifies in his question a specific number of examples they wish to obtain, always limit your query to at most {top_k} results. You can order the results by a relevant column to return the most interesting examples in the database.
#
# Never query for all the columns from a specific table, only ask for a the few relevant columns given the question.
#
# Pay attention to use only the column names that you can see in the schema description. Be careful to not query for columns that do not exist. Also, pay attention to which column is in which table.
#
# Only use the following tables:
# {table_info}
#
# Question: {input}

# %% [markdown]
# Populate the generated string ouptuted from the previous cell and fill it with an appropriate query

# %%
from typing_extensions import Annotated


class QueryOutput(TypedDict):
    """Generated SQL query."""

    query: Annotated[str, ..., "Syntactically valid SQL query."]


def write_query(state: State):
    """Generate SQL query to fetch information."""
    prompt = query_prompt_template.invoke(
        {
            "dialect": db.dialect,
            "top_k": 10,
            "table_info": db.get_table_info(),
            "input": state["question"],
        }
    )
    structured_llm = llm.with_structured_output(QueryOutput)
    result = structured_llm.invoke(prompt)
    return {"query": result["query"]}

# %%
write_query({"question": "How many Employees are there?"})
# Out:
# 2025-02-27 10:29:29,525 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:29:29,526 INFO sqlalchemy.engine.Engine SELECT "Artist"."ArtistId", "Artist"."Name"
# FROM "Artist"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:29:29,527 INFO sqlalchemy.engine.Engine [generated in 0.00164s] (3, 0)
# 2025-02-27 10:29:29,530 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:29:29,532 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:29:29,533 INFO sqlalchemy.engine.Engine SELECT "Employee"."EmployeeId", "Employee"."LastName", "Employee"."FirstName", "Employee"."Title", "Employee"."ReportsTo", "Employee"."BirthDate", "Employee"."HireDate", "Employee"."Address", "Employee"."City", "Employee"."State", "Employee"."Country", "Employee"."PostalCode", "Employee"."Phone", "Employee"."Fax", "Employee"."Email"
# FROM "Employee"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:29:29,533 INFO sqlalchemy.engine.Engine [generated in 0.00145s] (3, 0)
# 2025-02-27 10:29:29,536 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:29:29,537 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:29:29,541 INFO sqlalchemy.engine.Engine SELECT "Genre"."GenreId", "Genre"."Name"
# FROM "Genre"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:29:29,592 INFO sqlalchemy.engine.Engine [generated in 0.05562s] (3, 0)
# 2025-02-27 10:29:29,594 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:29:29,595 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:29:29,595 INFO sqlalchemy.engine.Engine SELECT "MediaType"."MediaTypeId", "MediaType"."Name"
# FROM "MediaType"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:29:29,596 INFO sqlalchemy.engine.Engine [generated in 0.00064s] (3, 0)
# 2025-02-27 10:29:29,597 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:29:29,599 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:29:29,599 INFO sqlalchemy.engine.Engine SELECT "Playlist"."PlaylistId", "Playlist"."Name"
# FROM "Playlist"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:29:29,599 INFO sqlalchemy.engine.Engine [generated in 0.00071s] (3, 0)
# 2025-02-27 10:29:29,600 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:29:29,602 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:29:29,607 INFO sqlalchemy.engine.Engine SELECT "Album"."AlbumId", "Album"."Title", "Album"."ArtistId"
# FROM "Album"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:29:29,611 INFO sqlalchemy.engine.Engine [generated in 0.00884s] (3, 0)
# 2025-02-27 10:29:29,613 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:29:29,615 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:29:29,615 INFO sqlalchemy.engine.Engine SELECT "Customer"."CustomerId", "Customer"."FirstName", "Customer"."LastName", "Customer"."Company", "Customer"."Address", "Customer"."City", "Customer"."State", "Customer"."Country", "Customer"."PostalCode", "Customer"."Phone", "Customer"."Fax", "Customer"."Email", "Customer"."SupportRepId"
# FROM "Customer"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:29:29,615 INFO sqlalchemy.engine.Engine [generated in 0.00051s] (3, 0)
# 2025-02-27 10:29:29,616 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:29:29,617 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:29:29,618 INFO sqlalchemy.engine.Engine SELECT "Invoice"."InvoiceId", "Invoice"."CustomerId", "Invoice"."InvoiceDate", "Invoice"."BillingAddress", "Invoice"."BillingCity", "Invoice"."BillingState", "Invoice"."BillingCountry", "Invoice"."BillingPostalCode", "Invoice"."Total"
# FROM "Invoice"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:29:29,618 INFO sqlalchemy.engine.Engine [generated in 0.00073s] (3, 0)
# 2025-02-27 10:29:29,619 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:29:29,620 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:29:29,620 INFO sqlalchemy.engine.Engine SELECT "Track"."TrackId", "Track"."Name", "Track"."AlbumId", "Track"."MediaTypeId", "Track"."GenreId", "Track"."Composer", "Track"."Milliseconds", "Track"."Bytes", "Track"."UnitPrice"
# FROM "Track"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:29:29,621 INFO sqlalchemy.engine.Engine [generated in 0.00042s] (3, 0)
# 2025-02-27 10:29:29,621 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:29:29,622 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:29:29,622 INFO sqlalchemy.engine.Engine SELECT "InvoiceLine"."InvoiceLineId", "InvoiceLine"."InvoiceId", "InvoiceLine"."TrackId", "InvoiceLine"."UnitPrice", "InvoiceLine"."Quantity"
# FROM "InvoiceLine"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:29:29,622 INFO sqlalchemy.engine.Engine [generated in 0.00038s] (3, 0)
# 2025-02-27 10:29:29,623 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:29:29,623 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:29:29,623 INFO sqlalchemy.engine.Engine SELECT "PlaylistTrack"."PlaylistId", "PlaylistTrack"."TrackId"
# FROM "PlaylistTrack"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:29:29,623 INFO sqlalchemy.engine.Engine [generated in 0.00035s] (3, 0)
# 2025-02-27 10:29:29,624 INFO sqlalchemy.engine.Engine ROLLBACK
# {'query': 'SELECT COUNT(*) AS EmployeeCount FROM Employee;'}

# %%
# TODO: find the way to create a technique to choose only the most appropriate tables from the list of tables the user have at the moment

# %% [markdown]
# Creating the method (tool) that is responsible for the running the generated query against the database

# %%
from langchain_community.tools.sql_database.tool import QuerySQLDatabaseTool

# notice that the instance of the state is passed along all the methods within a chain
def execute_query(state: State):
    """Execute SQL query."""
    execute_query_tool = QuerySQLDatabaseTool(db=db)
    return {"result": execute_query_tool.invoke(state["query"])}

# %% [markdown]
# The way how it can be called:

# %%
execute_query({"query": "SELECT COUNT(*) AS employee_count FROM employee;"})
# Out:
# 2025-02-27 10:29:54,730 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:29:54,731 INFO sqlalchemy.engine.Engine SELECT COUNT(*) AS employee_count FROM employee;
# 2025-02-27 10:29:54,731 INFO sqlalchemy.engine.Engine [generated in 0.00044s] ()
# 2025-02-27 10:29:54,733 INFO sqlalchemy.engine.Engine COMMIT
# {'result': '[(8,)]'}

# %% [markdown]
# The next tool is responsible for generation of the human like response. In future generations, should be changed to generation of the grpah

# %%
def generate_answer(state: State):
    """Answer question using retrieved information as context."""
    prompt = (
        "Given the following user question, corresponding SQL query, "
        "and SQL result, answer the user question.\n\n"
        f'Question: {state["question"]}\n'
        f'SQL Query: {state["query"]}\n'
        f'SQL Result: {state["result"]}'
    )
    response = llm.invoke(prompt)
    return {"answer": response.content}

# %% [markdown]
# Creating the pipeline of the chains to create the end-to-end agent

# %%
from langgraph.graph import START, StateGraph

graph_builder = StateGraph(State).add_sequence(
    [write_query, execute_query, generate_answer]
)
graph_builder.add_edge(START, "write_query") #setting write_query as the starting point
graph = graph_builder.compile()

# %% [markdown]
# Example of the possible interaction by the human in the chain

# %%
from langgraph.checkpoint.memory import MemorySaver

memory = MemorySaver()
# pay attention to the thing that the human interaction is inserted before running the execute_query
graph = graph_builder.compile(checkpointer=memory, interrupt_before=["execute_query"])

config = {"configurable": {"thread_id": "1"}}

# %% [markdown]
# Below is the possible way of how it can be integrated to the loop via wrapping the code in teh rty-catch block

# %%
for step in graph.stream(
    {"question": "How many employees are there?"},
    config,
    stream_mode="updates",
):
    print(step)

# loop should be prevented before running the query and the user's answer is passed forward

try:
    user_approval = input("Do you want to go to execute query? (yes/no): ")
except Exception:
    user_approval = "no"

if user_approval.lower() == "yes":
    # If approved, continue the graph execution
    for step in graph.stream(None, config, stream_mode="updates"):
        print(step)
else:
    print("Operation cancelled by user.")
# Out:
# 2025-02-27 10:30:08,664 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:30:08,665 INFO sqlalchemy.engine.Engine SELECT "Artist"."ArtistId", "Artist"."Name"
# FROM "Artist"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:30:08,666 INFO sqlalchemy.engine.Engine [cached since 39.14s ago] (3, 0)
# 2025-02-27 10:30:08,666 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:30:08,667 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:30:08,668 INFO sqlalchemy.engine.Engine SELECT "Employee"."EmployeeId", "Employee"."LastName", "Employee"."FirstName", "Employee"."Title", "Employee"."ReportsTo", "Employee"."BirthDate", "Employee"."HireDate", "Employee"."Address", "Employee"."City", "Employee"."State", "Employee"."Country", "Employee"."PostalCode", "Employee"."Phone", "Employee"."Fax", "Employee"."Email"
# FROM "Employee"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:30:08,668 INFO sqlalchemy.engine.Engine [cached since 39.14s ago] (3, 0)
# 2025-02-27 10:30:08,669 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:30:08,669 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:30:08,670 INFO sqlalchemy.engine.Engine SELECT "Genre"."GenreId", "Genre"."Name"
# FROM "Genre"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:30:08,670 INFO sqlalchemy.engine.Engine [cached since 39.13s ago] (3, 0)
# 2025-02-27 10:30:08,670 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:30:08,671 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:30:08,671 INFO sqlalchemy.engine.Engine SELECT "MediaType"."MediaTypeId", "MediaType"."Name"
# FROM "MediaType"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:30:08,671 INFO sqlalchemy.engine.Engine [cached since 39.08s ago] (3, 0)
# 2025-02-27 10:30:08,672 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:30:08,672 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:30:08,672 INFO sqlalchemy.engine.Engine SELECT "Playlist"."PlaylistId", "Playlist"."Name"
# FROM "Playlist"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:30:08,672 INFO sqlalchemy.engine.Engine [cached since 39.07s ago] (3, 0)
# 2025-02-27 10:30:08,673 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:30:08,674 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:30:08,674 INFO sqlalchemy.engine.Engine SELECT "Album"."AlbumId", "Album"."Title", "Album"."ArtistId"
# FROM "Album"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:30:08,674 INFO sqlalchemy.engine.Engine [cached since 39.07s ago] (3, 0)
# 2025-02-27 10:30:08,675 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:30:08,675 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:30:08,675 INFO sqlalchemy.engine.Engine SELECT "Customer"."CustomerId", "Customer"."FirstName", "Customer"."LastName", "Customer"."Company", "Customer"."Address", "Customer"."City", "Customer"."State", "Customer"."Country", "Customer"."PostalCode", "Customer"."Phone", "Customer"."Fax", "Customer"."Email", "Customer"."SupportRepId"
# FROM "Customer"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:30:08,675 INFO sqlalchemy.engine.Engine [cached since 39.06s ago] (3, 0)
# 2025-02-27 10:30:08,676 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:30:08,677 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:30:08,677 INFO sqlalchemy.engine.Engine SELECT "Invoice"."InvoiceId", "Invoice"."CustomerId", "Invoice"."InvoiceDate", "Invoice"."BillingAddress", "Invoice"."BillingCity", "Invoice"."BillingState", "Invoice"."BillingCountry", "Invoice"."BillingPostalCode", "Invoice"."Total"
# FROM "Invoice"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:30:08,677 INFO sqlalchemy.engine.Engine [cached since 39.06s ago] (3, 0)
# 2025-02-27 10:30:08,678 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:30:08,678 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:30:08,679 INFO sqlalchemy.engine.Engine SELECT "Track"."TrackId", "Track"."Name", "Track"."AlbumId", "Track"."MediaTypeId", "Track"."GenreId", "Track"."Composer", "Track"."Milliseconds", "Track"."Bytes", "Track"."UnitPrice"
# FROM "Track"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:30:08,679 INFO sqlalchemy.engine.Engine [cached since 39.06s ago] (3, 0)
# 2025-02-27 10:30:08,679 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:30:08,680 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:30:08,680 INFO sqlalchemy.engine.Engine SELECT "InvoiceLine"."InvoiceLineId", "InvoiceLine"."InvoiceId", "InvoiceLine"."TrackId", "InvoiceLine"."UnitPrice", "InvoiceLine"."Quantity"
# FROM "InvoiceLine"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:30:08,681 INFO sqlalchemy.engine.Engine [cached since 39.06s ago] (3, 0)
# 2025-02-27 10:30:08,682 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-02-27 10:30:08,683 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:30:08,684 INFO sqlalchemy.engine.Engine SELECT "PlaylistTrack"."PlaylistId", "PlaylistTrack"."TrackId"
# FROM "PlaylistTrack"
#  LIMIT ? OFFSET ?
# 2025-02-27 10:30:08,684 INFO sqlalchemy.engine.Engine [cached since 39.06s ago] (3, 0)
# 2025-02-27 10:30:08,685 INFO sqlalchemy.engine.Engine ROLLBACK
# {'write_query': {'query': 'SELECT COUNT(*) AS EmployeeCount FROM Employee;'}}
# {'__interrupt__': ()}
# 2025-02-27 10:30:11,717 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-27 10:30:11,718 INFO sqlalchemy.engine.Engine SELECT COUNT(*) AS EmployeeCount FROM Employee;
# 2025-02-27 10:30:11,718 INFO sqlalchemy.engine.Engine [generated in 0.00046s] ()
# 2025-02-27 10:30:11,720 INFO sqlalchemy.engine.Engine COMMIT
# {'execute_query': {'result': '[(8,)]'}}
# {'generate_answer': {'answer': 'There are 8 employees.'}}
